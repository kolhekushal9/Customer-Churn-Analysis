# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

df = pd.read_csv("telco_churn_featured.csv")

# Correlation heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# Hypothesis testing
churned = df[df['Churn'] == 1]['MonthlyCharges']
not_churned = df[df['Churn'] == 0]['MonthlyCharges']

t_stat, p_value = ttest_ind(churned, not_churned)
t_stat, p_value
# Out:
# (np.float64(-0.24019223070763066), np.float64(0.8112041043701135))
